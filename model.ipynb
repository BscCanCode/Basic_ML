# %%
import pandas as pd
df = pd.read_csv('student_scores.csv')
print(df)
# Out:
#        name  hours  score gender grades class
# 0     Aarav      8     76      M      A    9A
# 1      Riya      5     62      F      B    9B
# 2     Kabir     10     88      M      A   10A
# 3      Sana      4     55      F      C    9A
# 4    Vivaan      7     72      M      B   10B
# ..      ...    ...    ...    ...    ...   ...
# 87   Prisha      4     52      F      C    9A
# 88     Neil     10     88      M      A   12C
# 89    Rutvi      7     73      F      B   10A
# 90  Harshit      5     57      M      C    9B
# 91   Vritti      8     81      F      A   11B
#
# [92 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    92 non-null     object
#  1   hours   92 non-null     int64
#  2   score   92 non-null     int64
#  3   gender  92 non-null     object
#  4   grades  92 non-null     object
#  5   class   92 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 4.4+ KB

# %%
df.describe()
# Out:
#            hours      score
# count  92.000000  92.000000
# mean    6.510870  68.836957
# std     2.265336  15.692286
# min     2.000000  35.000000
# 25%     5.000000  57.000000
# 50%     7.000000  70.000000
# 75%     8.000000  82.000000
# max    11.000000  94.000000

# %%
df.columns.tolist()
# Out:
# ['name', 'hours', 'score', 'gender', 'grades', 'class']

# %%
df.dtypes
# Out:
# name      object
# hours      int64
# score      int64
# gender    object
# grades    object
# class     object
# dtype: object

# %%
(df.isnull().sum())
# Out:
# name      0
# hours     0
# score     0
# gender    0
# grades    0
# class     0
# dtype: int64

# %%
int(df.duplicated().sum())
# Out:
# 0

# %%
df['hours'].describe()
# Out:
# count    92.000000
# mean      6.510870
# std       2.265336
# min       2.000000
# 25%       5.000000
# 50%       7.000000
# 75%       8.000000
# max      11.000000
# Name: hours, dtype: float64

# %%
df['hours'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['gender'].value_counts(normalize='True')
# Out:
# gender
# F    0.51087
# M    0.48913
# Name: proportion, dtype: float64

# %% [markdown]
# | **Field**           | **Details**                                                                                                          |
# | ------------------- | -------------------------------------------------------------------------------------------------------------------- |
# | **Dataset Name**    | `students_scores.csv` *(demo dataset)*                                                                               |
# | **Description**     | It contains data of students which consist of scores, grades, name, class, etc., for performing data quality checks. |
# | **Features**        | `name`, `score`, `grade`, `gender`, `class`, `hours`                                                                 |
# | **Target Variable** | *None* (Exploratory dataset)                                                                                         |
# | **Number of Rows**  | 92                                                                                                                   |
# | **Null Handling**   | Non-null                                                                                                             |
# | **Transformations** | Performed boxplot analysis, value counts, and other exploratory data quality checks.                                 |
# | **Owner**           | Admin                                                                                                                |
# | **Last Updated**    | 2025-12-19                                                                                                           |

# %%
df.select_dtypes(include='object').columns
# Out:
# ['name', 'hours', 'score', 'gender', 'grades', 'class']

# %%
df.hist(bins=20)
# Out:
# array([[<Axes: title={'center': 'hours'}>,
#         <Axes: title={'center': 'score'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt
plt.plot(df['hours'],df['score'],color='black')

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
X= df[['hours']]
y = df['score']
model.fit(X,y)
print(model.coef_[0])
# Out:
# 6.849544957288835

# %%
X= df[['hours']]
y = df['score']
plt.scatter(X,y,color='blue',label='datapoints')
plt.plot(X,model.predict(X),color='red',label='line')
plt.legend()
plt.show()

# %%
from sklearn.model

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y,model.predict(X))
print("MSE:",mse)
# Out:
# MSE: 5.425739438080693
